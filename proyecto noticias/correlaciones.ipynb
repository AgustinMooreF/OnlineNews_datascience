# %%
# Tratamiento de datos
# ==============================================================================
import pandas as pd
import numpy as np


# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
from matplotlib import style

# Preprocesado y análisis
# ==============================================================================
import pingouin as pg
# Configuración matplotlib
# ==============================================================================
plt.style.use('ggplot')
import seaborn as sns
# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

# %%
datos = pd.read_csv('OnlineNewsPopularity.csv')

# %%
#se borran espacios en las keys de cada columna
datos.columns = datos.columns.str.replace(' ', '')

# %%
# for col in datos.columns:
#   se dropea URL ya que para efectos de este trabajo no sirve
datos.drop(columns=['url'],inplace=True)
datos.keys()
# print(datos[' shares'])
# Out:
# Index(['timedelta', 'n_tokens_title', 'n_tokens_content', 'n_unique_tokens',
#        'n_non_stop_words', 'n_non_stop_unique_tokens', 'num_hrefs',
#        'num_self_hrefs', 'num_imgs', 'num_videos', 'average_token_length',
#        'num_keywords', 'data_channel_is_lifestyle',
#        'data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min',
#        'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg',
#        'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares',
#        'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.scatter(x=datos.title_subjectivity, y=datos.title_sentiment_polarity, alpha= 1)
ax.set_xlabel('title_subjectivity') 
ax.set_ylabel('title_sentiment_polarity')
# Out:
# Text(0, 0.5, 'title_sentiment_polarity')

# %%
display(pg.corr(datos['title_subjectivity'], datos['title_sentiment_polarity'], method='pearson'))
display(pg.corr(datos['title_subjectivity'], datos['title_sentiment_polarity'], method='spearman'))
# Out:
#              n        r         CI95%  p-val BF10  power
# pearson  39644  0.23213  [0.22, 0.24]    0.0  inf    1.0
#               n         r         CI95%  p-val  power
# spearman  39644  0.351178  [0.34, 0.36]    0.0    1.0

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.scatter(x=datos.global_subjectivity, y=datos.global_sentiment_polarity, alpha= 0.8)
ax.set_xlabel('global_subjectivity') 
ax.set_ylabel('global_sentiment_polarity')
# Out:
# Text(0, 0.5, 'global_sentiment_polarity')

# %%
display(pg.corr(datos['global_subjectivity'], datos['global_sentiment_polarity'], method='pearson'))
display(pg.corr(datos['global_subjectivity'], datos['global_sentiment_polarity'], method='spearman'))
# Out:
#              n         r         CI95%  p-val BF10  power
# pearson  39644  0.339436  [0.33, 0.35]    0.0  inf    1.0
#               n         r         CI95%  p-val  power
# spearman  39644  0.336713  [0.33, 0.35]    0.0    1.0

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.scatter(x=datos.shares, y=datos.self_reference_avg_sharess, alpha= 0.8)
ax.set_xlabel('shares') 
ax.set_ylabel('self_reference_avg_shares')
# Out:
# Text(0, 0.5, 'self_reference_avg_shares')

# %%
display(pg.corr(datos['shares'], datos['self_reference_avg_sharess'], method='pearson'))
display(pg.corr(datos['shares'], datos['self_reference_avg_sharess'], method='spearman'))
# Out:
#              n         r         CI95%         p-val       BF10  power
# pearson  39644  0.057789  [0.05, 0.07]  1.102271e-30  3.918e+26    1.0
#               n         r        CI95%  p-val  power
# spearman  39644  0.192174  [0.18, 0.2]    0.0    1.0

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.scatter(x=datos.rate_negative_words, y=datos.avg_negative_polarity, alpha= 0.8)
ax.set_xlabel('rate_negative_words') 
ax.set_ylabel('avg_negative_polarity')
# Out:
# Text(0, 0.5, 'avg_negative_polarity')

# %%
display(pg.corr(datos['avg_negative_polarity'], datos['rate_negative_words'], method='pearson'))
display(pg.corr(datos['avg_negative_polarity'], datos['rate_negative_words'], method='spearman'))
# Out:
#              n         r           CI95%  p-val BF10  power
# pearson  39644 -0.346947  [-0.36, -0.34]    0.0  inf    1.0
#               n         r           CI95%  p-val  power
# spearman  39644 -0.325342  [-0.33, -0.32]    0.0    1.0

# %%
plt.figure(figsize=(40,40))
sns.heatmap(data=datos.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>
